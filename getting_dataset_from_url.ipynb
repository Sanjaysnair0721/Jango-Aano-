# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanj112/Jango-Aano-/blob/main/getting_dataset_from_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path='/content/drive/MyDrive/jackfruit_mango_classifier/training_set/chakkaurls.txt'
f=open(file_path,"r")
a=f.readlines()
print (a[0])
# Out:
# https://upload.wikimedia.org/wikipedia/commons/b/ba/Jackfruit_hanging.JPG

# %%
url1 = "https://thumbs.dreamstime.com/b/fruits-mango-scientific-name-mangifera-indica-anacardiaceae-ripened-fruit-piled-up-sale-thiruvananthapuram-kerala-india-48649430.jpg"
url2= "https://health.clevelandclinic.org/wp-content/uploads/sites/3/2020/12/eatJackfruit-823672534-770x533-1.jpg"
from imageio import imread
import cv2
import matplotlib.image as img
import matplotlib.pyplot as plt
image_path="/content/drive/MyDrive/jackfruit_mango_classifier/training_new_trial/chakka/"
i=1
image1 = imread(url1)
plt.imshow(image1)
for urll in a[185:]:
  print(urll)
  try:
    image = imread(urll)
    img.imsave(image_path+"chakka"+str(i)+".jpg",image)
    plt.imshow(image)
    i+=1
  except:
    continue
# Out:
# https://www.thehindubusinessline.com/news/national/article23315102.ece/ALTERNATES/LANDSCAPE_1200/BL22STATESJACKFRUIT
#
# https://m.economictimes.com/thumb/msid-65238707,width-640,height-480,resizemode-4,imgsize-130630/times-of-vegetarianism-bengaluru-eateries-are-creating-offbeat-dishes-with-jackfruit.jpg
#
# http://indiatogether.org/uploads/picture/image/1813/agr-jackfruit-2.jpg
#
# https://media.gettyimages.com/photos/closeup-of-jackfruit-against-white-background-picture-id1082518820?s=612x612
#
# https://www.peta.org/wp-content/uploads/2015/04/PETALiving-social-jackfruit-recipes-blow-your-mind-2.jpg
#
# https://img.i-scmp.com/cdn-cgi/image/fit=contain,width=1098,format=auto/sites/default/files/styles/1200x800/public/d8/images/methode/2019/07/12/ab56c0ae-a391-11e9-9a3c-98259c87fba2_image_hires_110748.jpg?itok=-PFkLRx1&v=1562900882
#
# https://media.fromthegrapevine.com/assets/images/2019/1/jackfruit.jpg.824x0_q71.jpg
#
# ...
